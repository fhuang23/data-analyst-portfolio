# %%
import pandas as pd

# %%
df = pd.read_csv("AI_Student_Life_India_2026.csv")

# %%
df.head(20)
# Out:
#     StudentID  Age  Gender EducationLevel                City  AIToolUsed  \
# 0           1   15  Female         School            Ludhiana   Grammarly
# 1           2   21  Female        College            Guwahati     ChatGPT
# 2           3   23  Female     University              Nagpur      Gemini
# 3           4   24  Female         School       Visakhapatnam     Copilot
# 4           5   16    Male         School            Gurugram     ChatGPT
# 5           6   22  Female        College         Bhubaneswar     ChatGPT
# 6           7   22    Male     University              Bhopal      Claude
# 7           8   21  Female     University              Kanpur  Perplexity
# 8           9   25  Female        College             Lucknow     ChatGPT
# 9          10   22  Female         School  Thiruvananthapuram     Copilot
# 10         11   22  Female     University            Ludhiana     Copilot
# 11         12   16  Female         School              Ranchi     Copilot
# ...

# %%
df.shape
# Out:
# (5000, 10)

# %%
df.describe()
# Out:
#          StudentID          Age  DailyUsageHours
# count  5000.000000  5000.000000      5000.000000
# mean   2500.500000    19.910400         3.485000
# std    1443.520003     3.166066         1.742666
# min       1.000000    15.000000         0.500000
# 25%    1250.750000    17.000000         2.000000
# 50%    2500.500000    20.000000         3.500000
# 75%    3750.250000    23.000000         5.000000
# max    5000.000000    25.000000         6.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          5000 non-null   int64
#  1   Age                5000 non-null   int64
#  2   Gender             5000 non-null   object
#  3   EducationLevel     5000 non-null   object
#  4   City               5000 non-null   object
#  5   AIToolUsed         5000 non-null   object
#  6   DailyUsageHours    5000 non-null   float64
#  7   Purpose            5000 non-null   object
#  8   ImpactonGrades     5000 non-null   object
#  9   SatisfactionLevel  5000 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 390.8+ KB

# %%
df["City"].value_counts()
# Out:
# City
# Lucknow               206
# Jaipur                201
# Mumbai                193
# Vijayawada            190
# Pune                  185
# Ludhiana              182
# Indore                182
# Nagpur                181
# Ranchi                178
# Guwahati              176
# Bhopal                176
# Ahmedabad             174
# Thiruvananthapuram    173
# Coimbatore            172
# Gurugram              171
# Noida                 170
# Mysuru                170
# Chandigarh            167
# Delhi                 167
# Surat                 164
# Kolkata               164
# Bhubaneswar           162
# Patna                 162
# Visakhapatnam         160
# Chennai               159
# Kochi                 157
# Hyderabad             154
# Bengaluru             153
# Kanpur                151
# Name: count, dtype: int64

# %%
1. Which students improved and how much was avg dailyusagehours
2. What is the breakdown of EducationLevel and Purpose?
3. Which AIToolUsed are used for what Purpose?
4. What are the total SUM DailyUsageHours broken down by Gender

# %%
1. Those who improved had an average use of 3.48 daily hours
2. Equal distribution of Educational Level using it for all purposes
3. Claude and Perplexity lead Writing (161)
   Grammarly lead Coding(158)
   NotionAI and Copilot lead Learning (157, 156)
   Gemini and Copilot lead Homework (156, 155)
4. Females have total: 9056 hours   Males have total: 8368 hours
